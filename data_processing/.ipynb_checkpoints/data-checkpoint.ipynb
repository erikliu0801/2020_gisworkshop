# %%
import pandas as pd

# %%
data = pd.read_csv('./lvr_landcsv/h_lvr_land_a.csv')

# %%
data
# Out:
#                                        鄉鎮市區              交易標的  \
# 0     The villages and towns urban district  transaction sign
# 1                                       桃園區      房地(土地+建物)+車位
# 2                                       桃園區      房地(土地+建物)+車位
# 3                                       桃園區      房地(土地+建物)+車位
# 4                                       桃園區      房地(土地+建物)+車位
# ...                                     ...               ...
# 1352                                    桃園區         房地(土地+建物)
# 1353                                    桃園區      房地(土地+建物)+車位
# 1354                                    桃園區      房地(土地+建物)+車位
# 1355                                    桃園區      房地(土地+建物)+車位
# 1356                                    桃園區      房地(土地+建物)+車位
#
#                                            土地區段位置建物區段門牌  \
# 0     land sector position building sector house num...
# 1                                          正光二街181~210號
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
dir(data)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
data.iloc[0:2]
# Out:
#                                     鄉鎮市區          交易標的  \
# 0  The villages and towns urban district
# 1                                    桃園區  房地(土地+建物)+車位
#
#                                         土地區段位置建物區段門牌  \
# 0  land sector position building sector house num...
# 1                                       正光二街181~210號
#
#                              土地移轉總面積平方公尺  \
# 0  land shifting total area square meter
# 1                                  31.83
#
#                                 都市土地使用分區  \
# 0  the use zoning or compiles and checks
# 1                                     其他
#
#                               非都市土地使用分區                非都市土地使用編定  \
# 0  the non-metropolis land use district  non-metropolis land use
# 1                                   NaN                      NaN
#
#                             交易年月日                   交易筆棟數            移轉層次  \
# 0  transaction year month and day  transaction pen number  shifting level
# ...

# %%
data.loc[0,2] = ""

# %%
data.loc[0,2]
# Out:
# ''

# %%
data.iloc[0,3]
# Out:
# 'land shifting total area square meter'

# %%
data.iloc[0,3] = 'land shifting total area square meter'

# %%
data.iloc[0:3]
# Out:
#                                     鄉鎮市區          交易標的  \
# 0  The villages and towns urban district
# 1                                    桃園區  房地(土地+建物)+車位
# 2                                    桃園區  房地(土地+建物)+車位
#
#                                         土地區段位置建物區段門牌  \
# 0  land sector position building sector house num...
# 1                                       正光二街181~210號
# 2                                       正光二街181~210號
#
#                              土地移轉總面積平方公尺  \
# 0  land shifting total area square meter
# 1                                  31.83
# 2                                  31.83
#
#                                 都市土地使用分區  \
# 0  the use zoning or compiles and checks
# 1                                     其他
# 2                                     其他
#
#                               非都市土地使用分區                非都市土地使用編定  \
# 0  the non-metropolis land use district  non-metropolis land use
# ...

# %%
addr = list(data['土地區段位置建物區段門牌'])

# %%
tmp = []
for x in addr:
    a = x.split('~')
    tmp.append(a)
print(tmp)
# Out:
# [['land sector position building sector house number plate'], ['正光二街181', '210號'], ['正光二街181', '210號'], ['正光二街181', '210號'], ['正光二街181巷1', '30號'], ['正光二街181巷1', '30號'], ['民富十一街1', '30號'], ['民富十一街1', '30號'], ['正光路186巷61', '90號'], ['大興路511', '540號'], ['藝文一街61', '90號'], ['小檜溪段271', '300地號'], ['龍鳳三街65巷1', '30號'], ['中埔六街151', '180號'], ['國際路二段121', '150號'], ['藝文一街31', '60號'], ['文中一路301', '330號'], ['天祥六街1', '30號'], ['大興西路二段181', '210號'], ['經國路198巷1', '30號'], ['慈德街91', '120號'], ['中華路31', '60號'], ['中華路31', '60號'], ['守法路31', '60號'], ['中壢埔頂段1561', '1590地號'], ['龍安六街1', '30號'], ['華美三路301', '330號'], ['華美三路301', '330號'], ['華美三路331', '360號'], ['華美三路331', '360號'], ['華美三路331', '360號'], ['華美三路301', '330號'], ['華美三路301', '330號'], ['華美三路331', '360號'], ['華美三路301', '330號'], ['華美三路301', '330號'], ['華美三路301', '330號'], ['華美三路331', '360號'], ['華美三路331', '360號'], ['華美三路331', '360號'], ['華美三路331', '360號'], ['華美三路331', '360號'], ['華美三路331', '360號'], ['華美三路301', '330號'], ['華美三路301', '330號'], ['華美三路301', '330號'], ['華美三路
# ...

# %%
for i, v  in enumerate(tmp):
    tmp[i] = v[0]
print(i)
# Out:
# 1356

# %%
tmp
# Out:
# ['land sector position building sector house number plate',
#  '正光二街181',
#  '正光二街181',
#  '正光二街181',
#  '正光二街181巷1',
#  '正光二街181巷1',
#  '民富十一街1',
#  '民富十一街1',
#  '正光路186巷61',
#  '大興路511',
#  '藝文一街61',
#  '小檜溪段271',
#  '龍鳳三街65巷1',
#  '中埔六街151',
#  '國際路二段121',
#  '藝文一街31',
#  '文中一路301',
#  '天祥六街1',
#  '大興西路二段181',
#  '經國路198巷1',
#  '慈德街91',
#  '中華路31',
#  '中華路31',
#  '守法路31',
#  '中壢埔頂段1561',
#  '龍安六街1',
#  '華美三路301',
#  '華美三路301',
#  '華美三路331',
#  '華美三路331',
#  '華美三路331',
#  '華美三路301',
#  '華美三路301',
#  '華美三路331',
#  '華美三路301',
#  '華美三路301',
#  '華美三路301',
#  '華美三路331',
#  '華美三路331',
#  '華美三路331',
#  '華美三路331',
#  '華美三路331',
#  '華美三路331',
#  '華美三路301',
#  '華美三路301',
#  '華美三路301',
#  '華美三路301',
#  '華美三路331',
#  '華美三路301',
#  '華美三路301',
#  '華美三路301',
#  '華美三路331',
#  '華美三路301',
#  '華美三路301',
#  '華美三路301',
#  '華美三路331',
#  '三座屋段舊社小段31',
#  '華美三路331',
#  '華美三路301',
#  '華美三路331',
#  '華美三路331',
#  '領航南路三段91',
#  '甘泉段451',
#  '華美三路301',
#  '吉祥街81巷31',
#  '吉祥街81巷31',
#  '華美三路301',
# ...
